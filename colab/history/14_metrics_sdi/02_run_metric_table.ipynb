# %% [markdown]
# # Supplied run inventory / فهرست اجرای کاربر
# Retrospective reconstruction; this is not an original timestamped development artifact and results require rerunning. Set `PREDICTION_GLOB`; this notebook does not contain benchmark results.

# %%
import glob
import json
import os
from pathlib import Path
pattern = os.environ.get('PREDICTION_GLOB', 'no_predictions_selected_*.json')
files = [Path(name) for name in sorted(glob.glob(pattern))]
files

# %%
def rows(payload):
    if isinstance(payload, list): return payload
    for key in ('records', 'predictions', 'items'):
        if isinstance(payload.get(key), list): return payload[key]
    raise ValueError('unsupported schema')
inventory = [{'path': str(path), 'records': len(rows(json.loads(path.read_text(encoding='utf-8'))))} for path in files]
inventory

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':3,'status':'not_executed'}
print(scratch)

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':5,'status':'not_executed'}
print(scratch)

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':7,'status':'not_executed'}
print(scratch)

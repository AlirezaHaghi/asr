# %% [markdown]
# # Whisper vs XLS-R CTC / مقایسه دو معماری
# Retrospective reconstruction created from the final notebook/report. It is not claimed to be an original timestamped development artifact; generated metrics require rerunning.

# %%
RUNS = [
 {'run_id':'whisper_encoder_decoder','architecture':'encoder-decoder','model_id':'jacktol/whisper-large-v3-finetuned-for-ATC','decoding':'beam search'},
 {'run_id':'xlsr_ctc','architecture':'CTC','model_id':'Jzuluaga/wav2vec2-xls-r-300m-en-atc-uwb-atcc-and-atcosim','decoding':'CTC pipeline'},
]
RUNS

# %% [markdown]
# ## Controlled variables / متغیرهای کنترل‌شده
# Use the same ordered audio hashes, reference text, normalization, hardware session, and failure policy. The checkpoints still differ in training data and size.

# %%
required_fields = {'id','audio_sha256','reference_raw','hypothesis_raw','inference_s','status'}
assert len({r['model_id'] for r in RUNS}) == 2
print({'planned_runs':len(RUNS), 'required_observation_fields':sorted(required_fields), 'metrics_available_now':False})

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':5,'status':'not_executed'}
print(scratch)

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':7,'status':'not_executed'}
print(scratch)

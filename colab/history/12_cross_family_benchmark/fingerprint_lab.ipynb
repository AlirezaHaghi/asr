# %% [markdown]
# # Config fingerprint lab / آزمایش اثرانگشت تنظیمات
# Retrospective reconstruction; this is not an original timestamped development artifact and results require rerunning. This notebook checks canonicalization behavior, not project outputs.

# %%
import hashlib
import json
def fingerprint(value):
    raw = json.dumps(value, sort_keys=True, separators=(',', ':'), allow_nan=False).encode('utf-8')
    return hashlib.sha256(raw).hexdigest()
left = {'model': 'user/model', 'generate_kwargs': {'num_beams': 1}}
right = {'generate_kwargs': {'num_beams': 1}, 'model': 'user/model'}
fingerprint(left), fingerprint(right)

# %%
assert fingerprint(left) == fingerprint(right)
changed = {**left, 'generate_kwargs': {'num_beams': 5}}
assert fingerprint(left) != fingerprint(changed)
'canonical key order is stable; beam changes provenance'

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':3,'status':'not_executed'}
print(scratch)

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':5,'status':'not_executed'}
print(scratch)

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':7,'status':'not_executed'}
print(scratch)

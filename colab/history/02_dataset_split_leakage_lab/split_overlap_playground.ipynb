# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
train=[{'id':'a','text':'contact tower'},{'id':'b','text':'runway two eight'}]
eval_rows=[{'id':'c','text':'contact tower'},{'id':'d','text':'climb flight level one eight zero'}]
print(train,eval_rows)

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
import re
def key(text): return re.sub(r'\s+',' ',re.sub(r'[^a-z0-9 ]',' ',text.lower())).strip()
print([key(r['text']) for r in train])

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
left={key(r['text']) for r in train}
right={key(r['text']) for r in eval_rows}
print('toy overlap:',sorted(left & right))

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':7,'status':'not_executed'}
print(scratch)

# %%
# Retrospective reconstruction; rerun for real results. | # خودمونی: overlap رو پیدا کردی قایمش نکن؛ اول گزارش بده.\nprint('یادداشت فارسی آماده‌ست؛ نتیجه واقعی بعد از rerun')

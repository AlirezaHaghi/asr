# %% [markdown]
# # Taxonomy explorer / مرور دسته‌بندی خطا
# Retrospective reconstruction; this is not an original timestamped development artifact and results require rerunning. Point `ERROR_JSON` to a generated taxonomy file.

# %%
import json
import os
from collections import Counter
from pathlib import Path
path = Path(os.environ['ERROR_JSON']) if os.environ.get('ERROR_JSON') else None
errors = json.loads(path.read_text(encoding='utf-8')).get('errors', []) if path else []
{'selected': str(path) if path else None, 'errors': len(errors)}

# %%
by_category = Counter(item.get('category', 'missing') for item in errors)
by_operation = Counter(item.get('operation', 'missing') for item in errors)
{'category': dict(by_category), 'operation': dict(by_operation)}

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':3,'status':'not_executed'}
print(scratch)

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':5,'status':'not_executed'}
print(scratch)

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':7,'status':'not_executed'}
print(scratch)

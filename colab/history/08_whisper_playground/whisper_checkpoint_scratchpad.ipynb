# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
items=['jacktol/whisper-large-v3-finetuned-for-ATC', 'tclin/whisper-large-v3-turbo-atcosim', 'youngsangroh/whisper-small-atco2-atcosim']
print(items)

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
plans=[{'item':item,'status':'planned_not_executed'} for item in items]
for row in plans: print(row)

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
def tag(value):
    return str(value).lower().replace(' ','_').replace('/','__')
print([tag(item) for item in items])

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':7,'status':'not_executed'}
print(scratch)

# %%
# Retrospective reconstruction; rerun for real results. | # خودمونی: همه Whisperها باید دقیقاً همون audio رو بگیرن.\nprint('یادداشت فارسی آماده‌ست؛ نتیجه واقعی بعد از rerun')

# %% [markdown]
# # Decoding grid design / طراحی شبکه رمزگشایی
# Retrospective reconstruction created from the final notebook/report. It is not claimed to be an original timestamped development artifact; generated metrics require rerunning.

# %%
MODEL_ID = 'jacktol/whisper-large-v3-finetuned-for-ATC'
BEAMS = [1, 5, 10]
grid = [{'run_id': f'beam_{b}', 'model_id': MODEL_ID, 'generate_kwargs': {'language':'english','task':'transcribe','num_beams':b,'do_sample':False}} for b in BEAMS]
grid

# %% [markdown]
# Beam search is deterministic decoding; temperature sampling should be a separate family. / beam و temperature نباید بدون کنترل با هم مخلوط شوند.

# %%
assert len({r['run_id'] for r in grid}) == len(grid)
assert len({r['model_id'] for r in grid}) == 1
print(f'{len(grid)} configs ready; no metrics exist until inference is rerun')

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':5,'status':'not_executed'}
print(scratch)

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':7,'status':'not_executed'}
print(scratch)

# %% [markdown]
# # RTF measurement lab / آزمایش ضریب بلادرنگ
# Retrospective reconstruction; this is not an original timestamped development artifact and results require rerunning. The timed operation below demonstrates the formula only.

# %%
import time
audio_duration_seconds = 1.0
started = time.perf_counter()
sum(index*index for index in range(10000))
wall_seconds = time.perf_counter() - started
{'wall_seconds': wall_seconds, 'audio_seconds': audio_duration_seconds, 'rtf': wall_seconds/audio_duration_seconds}

# %% [markdown]
# For CUDA timing, synchronize before and after inference. Model load time should remain separate. / برای GPU همگام‌سازی لازم است.

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':3,'status':'not_executed'}
print(scratch)

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':5,'status':'not_executed'}
print(scratch)

# %% [markdown]
# ## Quick scratch check
#
# This cell keeps the notebook flow readable; rerun the real experiment cells for results.

# %%
# Small scratch check; rerun for real outputs.
scratch={'cell':7,'status':'not_executed'}
print(scratch)
